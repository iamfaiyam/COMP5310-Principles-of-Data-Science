# %% [markdown]
# # Data transformation, cleaning and loading with Python
#
# ## WaterInfo Data Set
# We are considering a water data set this week about Murray River Basin in NSW. We have made available the content of the Excel workbook as a set of four different CSV files. Please upload those CSV files to Jupyter first.
#
# **Important:** Make sure that the naming of all the files is as follows:
#  1. Measurements.csv
#  2. Organisations.csv
#  3. Sensors.csv
#  4. Stations.csv

# %% [markdown]
# # EXERCISE 1: Data Loading and Database Creation with Python
#
# We continue with the same Python environment: the `DictReader` from the `csv` module which support reading and writing of files in comma-separated values (CSV).
#
# Make sure that you have uploaded the 'Organisations.csv' CSV file into Jupyter.
# We will first load the content of this file into Python with the same  csv.DictReader()  mechanism:

# %%
import csv
import pprint
data_organisations = list(csv.DictReader(open('Organisations.csv')))
pprint.pprint(data_organisations[0])
# Out:
# {'Code': 'DNR',
#  'Organisation': 'NSW Department of Water and Energy (and predecessors)'}

# %% [markdown]
# For larger data sets, the following would normally be executed as a stand alone Python program on a shell.
# First, you need to establish a connection to the postgresql database.
# __Please edit the YOUR_DBNAME, YOUR_USERNAME and YOUR_PW variables in the Credentials.json file to match your database login. (Refer to the sample josn file provided)__

# %%
#!pip install psycopg2-binary

# %%
import psycopg2
import json

f = open('Credentials.json')
db_conn_dict = json.load(f)
YOUR_DBNAME =  db_conn_dict['database']
YOUR_USERNAME = db_conn_dict['user']
YOUR_PW = db_conn_dict['password']

def pgconnect():
  
    try: 
        conn = psycopg2.connect(host='localhost',
                                database=YOUR_DBNAME,
                                user=YOUR_USERNAME, 
                                password=YOUR_PW)
        print('connected')
    except Exception as e:
        print("unable to connect to the database")
        print(e)
    return conn

# %% [markdown]
# We will need to execute some SQL statements against the database. As we will have to do so multiple times, we write a dedicated function for executing an arbitrary SQL statement, where we do not expect any result. This handles then also all failures and using psycopg2's 'with' statements also the transaction processing of the database. Below's code will for example automatically commit our SQL statements, as well as rollback if there was any error.

# %%
def pgexec( conn, sqlcmd, args, msg, silent=False ):
   """ utility function to execute some SQL statement
       can take optional arguments to fill in (dictionary)
       error and transaction handling built-in """
   retval = False
   with conn:
      with conn.cursor() as cur:
         try:
            if args is None:
               cur.execute(sqlcmd)
            else:
               cur.execute(sqlcmd, args)
            if silent == False: 
                print("success: " + msg)
            retval = True
         except Exception as e:
            if silent == False: 
                print("db error: ")
                print(e)
   return retval

# %% [markdown]
# Now let's load our previous data.
# Important: whenever you use this approach, make sure that the header line of your CSV file has no spaces in its column titles and also no quotes. Otherwise, the csv.DictReader might be fine to read it, but not the psycopg2's cursor.execute() function. We are using named placeholders in out INSERT statement below (eg. '%(SiteName)s' ) which expects to put a string (%s) into that place of the INSERT statement as been found in the given dictionary for the execute() call with the key 'SiteName'.

# %%
# 1st: login to database
conn = pgconnect()

# if you want to reset the table
pgexec (conn, "DROP TABLE IF EXISTS Organisation", None, "Reset Table Organisation")

# 2nd: ensure that the schema is in place

organisation_schema = """CREATE TABLE IF NOT EXISTS Organisation (
                         code VARCHAR(20) PRIMARY KEY,
                         orgName VARCHAR(150)
                   )"""
pgexec (conn, organisation_schema, None, "Create Table Organisation")

# 3nd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Organisation(code,orgName) VALUES (%(Code)s, %(Organisation)s)"""
for row in data_organisations:
    pgexec (conn, insert_stmt, row, "row inserted")
# Out:
# connected
# success: Reset Table Organisation
# success: Create Table Organisation
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted

# %% [markdown]
# Next let's check whether this has all worked fine by querying our PostgreSQL database. To do so, we introduce first another utility function which again encapsulates all error and transaction handling. Then we query the new Organisation table and simply print out all tuples found.

# %%
def pgquery( conn, sqlcmd, args, silent=False ):
   """ utility function to execute some SQL query statement
       can take optional arguments to fill in (dictionary)
       will print out on screen the result set of the query
       error and transaction handling built-in """
   retval = False
   with conn:
      with conn.cursor() as cur:
         try:
            if args is None:
                cur.execute(sqlcmd)
            else:
                cur.execute(sqlcmd, args)
            if silent == False:
                for record in cur:
                    print(record)
            retval = True
         except Exception as e:
            if silent == False:
                print("db read error: ")
                print(e)
   return retval

# %%
# check content of Organisation table
query_stmt = "SELECT * FROM Organisation"
print(query_stmt)
pgquery (conn, query_stmt, None)

# cleanup...   Needed already?  Better not now... 
# But keep in mind to close connection eventually!
# conn.close()
# Out:
# SELECT * FROM Organisation
# ('DNR', 'NSW Department of Water and Energy (and predecessors)')
# ('DWR', 'NSW Department of Water and Energy (and predecessors)')
# ('MIL', 'Murray Irrigation Ltd')
# ('PWD', 'Manly Hydraulics Laboratory')
# ('QWR', 'Qld Department of Natural Resources and Water')
# ('SCA', 'Sydney Catchment Authority')
# ('SMA', 'Snowy Mountains Authority')
# ('SWB', 'Sydney Catchment Authority')
# ('VRW', 'Vic Government')
# True

# %% [markdown]
# ## Your Task: Data Loading
#
# Try to create and load the Measurement table.
#
#     1.read the Measurements csv file
#     2. Create a matching 'Measurement' table to hold the CSV data
#     3. Load the content of the csv file into a local 'data_measurements' dictionary in Python
#     4. Load the data from the 'data_measurements' dictionary into your PostgreSQL table
#     5. Query and print its content

# %%
# TODO: replace the content of this cell with your Python + psycopg2 solution
data_measurements = list(csv.DictReader(open('Measurements.csv')))
pprint.pprint(data_measurements[0])
# Out:
# {'Date': '31/12/2004',
#  'Discharge': '5873.837',
#  'EC': '57.583',
#  'Level': '1.196',
#  'MeanDischarge': '5876.087',
#  'Station': '409204C',
#  'Temp': '23.217'}

# %%
# if you want to reset the table
pgexec(conn, "DROP TABLE IF EXISTS Measuremnt", None, "Reset Table Measurement")

# 2nd: ensure that the schema is in place
measurement_schema = """CREATE TABLE IF NOT EXISTS Measurement ( 
                        station VARCHAR(20), 
                        date DATE, 
                        level FLOAT, 
                        meanDischarge FLOAT, 
                        discharge FLOAT, 
                        temp VARCHAR(20), 
                        ec VARCHAR(20)
                    )"""
pgexec(conn, measurement_schema, None, "Create Table Measurement")
# Out:
# success: Reset Table Measurement
# success: Create Table Measurement
# True

# %%
# 3rd: load data 
# IMPORTANT: make sure the header line of CSV is without spaces! 
insert_stmt = """INSERT INTO Measurement(station, date, level, meandischarge, discharge, temp, ec)
                    VALUES (%(Station)s, %(Date)s, %(Level)s, %(MeanDischarge)s, %(Discharge)s, %(Temp)s, %(EC)s)"""

for row in data_measurements:
    pgexec(conn, insert_stmt, row, "row inserted")
# Out:
# db error:
# date/time field value out of range: "31/12/2004"
# LINE 2:                     VALUES ('409204C', '31/12/2004', '1.196'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/12/2004"
# LINE 2:                     VALUES ('219018', '31/12/2004', '0.219',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/12/2004"
# LINE 2:                     VALUES ('409017', '31/12/2004', '2.552',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# date/time field value out of range: "13/01/2005"
# LINE 2:                     VALUES ('409204C', '13/01/2005', '1.043'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/01/2005"
# LINE 2:                     VALUES ('219018', '13/01/2005', '0.179',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/01/2005"
# LINE 2:                     VALUES ('409017', '13/01/2005', '2.586',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/01/2005"
# LINE 2:                     VALUES ('409204C', '14/01/2005', '1.036'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/01/2005"
# LINE 2:                     VALUES ('219018', '14/01/2005', '0.167',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/01/2005"
# LINE 2:                     VALUES ('409017', '14/01/2005', '2.593',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/01/2005"
# LINE 2:                     VALUES ('409204C', '15/01/2005', '1.018'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/01/2005"
# LINE 2:                     VALUES ('219018', '15/01/2005', '0.154',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/01/2005"
# LINE 2:                     VALUES ('409017', '15/01/2005', '2.607',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/01/2005"
# LINE 2:                     VALUES ('409204C', '16/01/2005', '0.995'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/01/2005"
# LINE 2:                     VALUES ('219018', '16/01/2005', '0.115',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/01/2005"
# LINE 2:                     VALUES ('409017', '16/01/2005', '2.65', ...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/01/2005"
# LINE 2:                     VALUES ('409204C', '17/01/2005', '0.976'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/01/2005"
# LINE 2:                     VALUES ('219018', '17/01/2005', '0.078',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/01/2005"
# LINE 2:                     VALUES ('409017', '17/01/2005', '2.622',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/01/2005"
# LINE 2:                     VALUES ('409204C', '18/01/2005', '0.951'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/01/2005"
# LINE 2:                     VALUES ('219018', '18/01/2005', '0.047',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/01/2005"
# LINE 2:                     VALUES ('409017', '18/01/2005', '2.638',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/01/2005"
# LINE 2:                     VALUES ('409204C', '19/01/2005', '0.918'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/01/2005"
# LINE 2:                     VALUES ('219018', '19/01/2005', '0.013',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/01/2005"
# LINE 2:                     VALUES ('409017', '19/01/2005', '2.634',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/01/2005"
# LINE 2:                     VALUES ('409204C', '20/01/2005', '0.896'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/01/2005"
# LINE 2:                     VALUES ('219018', '20/01/2005', '-0.018'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/01/2005"
# LINE 2:                     VALUES ('409017', '20/01/2005', '2.672',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/01/2005"
# LINE 2:                     VALUES ('409204C', '21/01/2005', '0.894'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/01/2005"
# LINE 2:                     VALUES ('219018', '21/01/2005', '-0.036'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/01/2005"
# LINE 2:                     VALUES ('409017', '21/01/2005', '2.718',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/01/2005"
# LINE 2:                     VALUES ('409204C', '22/01/2005', '0.89',...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/01/2005"
# LINE 2:                     VALUES ('219018', '22/01/2005', '-0.007'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/01/2005"
# LINE 2:                     VALUES ('409017', '22/01/2005', '2.741',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/01/2005"
# LINE 2:                     VALUES ('409204C', '23/01/2005', '0.878'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/01/2005"
# LINE 2:                     VALUES ('219018', '23/01/2005', '-0.029'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/01/2005"
# LINE 2:                     VALUES ('409017', '23/01/2005', '2.701',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/01/2005"
# LINE 2:                     VALUES ('409204C', '24/01/2005', '0.881'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/01/2005"
# LINE 2:                     VALUES ('219018', '24/01/2005', '-0.068'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/01/2005"
# LINE 2:                     VALUES ('409017', '24/01/2005', '2.653',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/01/2005"
# LINE 2:                     VALUES ('409204C', '25/01/2005', '0.888'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/01/2005"
# LINE 2:                     VALUES ('219018', '25/01/2005', '-0.113'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/01/2005"
# LINE 2:                     VALUES ('409017', '25/01/2005', '2.65', ...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/01/2005"
# LINE 2:                     VALUES ('409204C', '26/01/2005', '0.909'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/01/2005"
# LINE 2:                     VALUES ('219018', '26/01/2005', '-0.166'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/01/2005"
# LINE 2:                     VALUES ('409017', '26/01/2005', '2.688',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/01/2005"
# LINE 2:                     VALUES ('409204C', '27/01/2005', '0.923'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/01/2005"
# LINE 2:                     VALUES ('219018', '27/01/2005', '-0.225'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/01/2005"
# LINE 2:                     VALUES ('409017', '27/01/2005', '2.725',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/01/2005"
# LINE 2:                     VALUES ('409204C', '28/01/2005', '0.937'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/01/2005"
# LINE 2:                     VALUES ('219018', '28/01/2005', '-0.248'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/01/2005"
# LINE 2:                     VALUES ('409017', '28/01/2005', '2.717',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/01/2005"
# LINE 2:                     VALUES ('409204C', '29/01/2005', '0.956'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/01/2005"
# LINE 2:                     VALUES ('219018', '29/01/2005', '-0.246'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/01/2005"
# LINE 2:                     VALUES ('409017', '29/01/2005', '2.741',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/01/2005"
# LINE 2:                     VALUES ('409204C', '30/01/2005', '0.981'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/01/2005"
# LINE 2:                     VALUES ('219018', '30/01/2005', '-0.247'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/01/2005"
# LINE 2:                     VALUES ('409017', '30/01/2005', '2.814',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/01/2005"
# LINE 2:                     VALUES ('409204C', '31/01/2005', '1.001'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/01/2005"
# LINE 2:                     VALUES ('219018', '31/01/2005', '-0.248'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/01/2005"
# LINE 2:                     VALUES ('409017', '31/01/2005', '2.814',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# date/time field value out of range: "13/02/2005"
# LINE 2:                     VALUES ('409204C', '13/02/2005', '1.128'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/02/2005"
# LINE 2:                     VALUES ('219018', '13/02/2005', '-0.248'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/02/2005"
# LINE 2:                     VALUES ('409017', '13/02/2005', '2.774',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/02/2005"
# LINE 2:                     VALUES ('409204C', '14/02/2005', '1.138'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/02/2005"
# LINE 2:                     VALUES ('219018', '14/02/2005', '-0.248'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/02/2005"
# LINE 2:                     VALUES ('409017', '14/02/2005', '2.699',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/02/2005"
# LINE 2:                     VALUES ('409204C', '15/02/2005', '1.146'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/02/2005"
# LINE 2:                     VALUES ('219018', '15/02/2005', '-0.247'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/02/2005"
# LINE 2:                     VALUES ('409017', '15/02/2005', '2.7', '...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/02/2005"
# LINE 2:                     VALUES ('409204C', '16/02/2005', '1.149'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/02/2005"
# LINE 2:                     VALUES ('219018', '16/02/2005', '-0.243'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/02/2005"
# LINE 2:                     VALUES ('409017', '16/02/2005', '2.721',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/02/2005"
# LINE 2:                     VALUES ('409204C', '17/02/2005', '1.157'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/02/2005"
# LINE 2:                     VALUES ('219018', '17/02/2005', '-0.206'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/02/2005"
# LINE 2:                     VALUES ('409017', '17/02/2005', '2.72', ...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/02/2005"
# LINE 2:                     VALUES ('409204C', '18/02/2005', '1.172'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/02/2005"
# LINE 2:                     VALUES ('219018', '18/02/2005', '-0.157'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/02/2005"
# LINE 2:                     VALUES ('409017', '18/02/2005', '2.696',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/02/2005"
# LINE 2:                     VALUES ('409204C', '19/02/2005', '1.183'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/02/2005"
# LINE 2:                     VALUES ('219018', '19/02/2005', '-0.093'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/02/2005"
# LINE 2:                     VALUES ('409017', '19/02/2005', '2.681',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/02/2005"
# LINE 2:                     VALUES ('409204C', '20/02/2005', '1.187'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/02/2005"
# LINE 2:                     VALUES ('219018', '20/02/2005', '-0.064'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/02/2005"
# LINE 2:                     VALUES ('409017', '20/02/2005', '2.694',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/02/2005"
# LINE 2:                     VALUES ('409204C', '21/02/2005', '1.192'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/02/2005"
# LINE 2:                     VALUES ('219018', '21/02/2005', '-0.02',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/02/2005"
# LINE 2:                     VALUES ('409017', '21/02/2005', '2.722',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/02/2005"
# LINE 2:                     VALUES ('409204C', '22/02/2005', '1.198'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/02/2005"
# LINE 2:                     VALUES ('219018', '22/02/2005', '0.021',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/02/2005"
# LINE 2:                     VALUES ('409017', '22/02/2005', '2.72', ...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/02/2005"
# LINE 2:                     VALUES ('409204C', '23/02/2005', '1.202'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/02/2005"
# LINE 2:                     VALUES ('219018', '23/02/2005', '0.046',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/02/2005"
# LINE 2:                     VALUES ('409017', '23/02/2005', '2.721',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/02/2005"
# LINE 2:                     VALUES ('409204C', '24/02/2005', '1.206'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/02/2005"
# LINE 2:                     VALUES ('219018', '24/02/2005', '0.053',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/02/2005"
# LINE 2:                     VALUES ('409017', '24/02/2005', '2.721',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/02/2005"
# LINE 2:                     VALUES ('409204C', '25/02/2005', '1.223'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/02/2005"
# LINE 2:                     VALUES ('219018', '25/02/2005', '0.055',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/02/2005"
# LINE 2:                     VALUES ('409017', '25/02/2005', '2.723',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/02/2005"
# LINE 2:                     VALUES ('409204C', '26/02/2005', '1.234'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/02/2005"
# LINE 2:                     VALUES ('219018', '26/02/2005', '0.045',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/02/2005"
# LINE 2:                     VALUES ('409017', '26/02/2005', '2.728',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/02/2005"
# LINE 2:                     VALUES ('409204C', '27/02/2005', '1.24',...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/02/2005"
# LINE 2:                     VALUES ('219018', '27/02/2005', '0.033',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/02/2005"
# LINE 2:                     VALUES ('409017', '27/02/2005', '2.714',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/02/2005"
# LINE 2:                     VALUES ('409204C', '28/02/2005', '1.239'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/02/2005"
# LINE 2:                     VALUES ('219018', '28/02/2005', '0.017',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/02/2005"
# LINE 2:                     VALUES ('409017', '28/02/2005', '2.684',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# date/time field value out of range: "13/03/2005"
# LINE 2:                     VALUES ('409204C', '13/03/2005', '1.186'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/03/2005"
# LINE 2:                     VALUES ('219018', '13/03/2005', '0.052',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/03/2005"
# LINE 2:                     VALUES ('409017', '13/03/2005', '2.626',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/03/2005"
# LINE 2:                     VALUES ('409204C', '14/03/2005', '1.169'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/03/2005"
# LINE 2:                     VALUES ('219018', '14/03/2005', '0.067',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/03/2005"
# LINE 2:                     VALUES ('409017', '14/03/2005', '2.6', '...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/03/2005"
# LINE 2:                     VALUES ('409204C', '15/03/2005', '1.146'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/03/2005"
# LINE 2:                     VALUES ('219018', '15/03/2005', '0.104',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/03/2005"
# LINE 2:                     VALUES ('409017', '15/03/2005', '2.589',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/03/2005"
# LINE 2:                     VALUES ('409204C', '16/03/2005', '1.127'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/03/2005"
# LINE 2:                     VALUES ('219018', '16/03/2005', '0.119',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/03/2005"
# LINE 2:                     VALUES ('409017', '16/03/2005', '2.581',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/03/2005"
# LINE 2:                     VALUES ('409204C', '17/03/2005', '1.106'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/03/2005"
# LINE 2:                     VALUES ('219018', '17/03/2005', '0.117',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/03/2005"
# LINE 2:                     VALUES ('409017', '17/03/2005', '2.559',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/03/2005"
# LINE 2:                     VALUES ('409204C', '18/03/2005', '1.078'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/03/2005"
# LINE 2:                     VALUES ('219018', '18/03/2005', '0.102',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/03/2005"
# LINE 2:                     VALUES ('409017', '18/03/2005', '2.496',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/03/2005"
# LINE 2:                     VALUES ('409204C', '19/03/2005', '1.056'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/03/2005"
# LINE 2:                     VALUES ('219018', '19/03/2005', '0.082',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/03/2005"
# LINE 2:                     VALUES ('409017', '19/03/2005', '2.44', ...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/03/2005"
# LINE 2:                     VALUES ('409204C', '20/03/2005', '1.028'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/03/2005"
# LINE 2:                     VALUES ('219018', '20/03/2005', '0.053',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/03/2005"
# LINE 2:                     VALUES ('409017', '20/03/2005', '2.459',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/03/2005"
# LINE 2:                     VALUES ('409204C', '21/03/2005', '0.997'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/03/2005"
# LINE 2:                     VALUES ('219018', '21/03/2005', '0.024',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/03/2005"
# LINE 2:                     VALUES ('409017', '21/03/2005', '2.452',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/03/2005"
# LINE 2:                     VALUES ('409204C', '22/03/2005', '0.964'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/03/2005"
# LINE 2:                     VALUES ('219018', '22/03/2005', '-0.002'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/03/2005"
# LINE 2:                     VALUES ('409017', '22/03/2005', '2.45', ...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/03/2005"
# LINE 2:                     VALUES ('409204C', '23/03/2005', '0.929'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/03/2005"
# LINE 2:                     VALUES ('219018', '23/03/2005', '-0.031'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/03/2005"
# LINE 2:                     VALUES ('409017', '23/03/2005', '2.452',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/03/2005"
# LINE 2:                     VALUES ('409204C', '24/03/2005', '0.903'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/03/2005"
# LINE 2:                     VALUES ('219018', '24/03/2005', '-0.065'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/03/2005"
# LINE 2:                     VALUES ('409017', '24/03/2005', '2.442',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/03/2005"
# LINE 2:                     VALUES ('409204C', '25/03/2005', '0.878'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/03/2005"
# LINE 2:                     VALUES ('219018', '25/03/2005', '-0.093'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/03/2005"
# LINE 2:                     VALUES ('409017', '25/03/2005', '2.45', ...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/03/2005"
# LINE 2:                     VALUES ('409204C', '26/03/2005', '0.851'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/03/2005"
# LINE 2:                     VALUES ('219018', '26/03/2005', '-0.104'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/03/2005"
# LINE 2:                     VALUES ('409017', '26/03/2005', '2.456',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/03/2005"
# LINE 2:                     VALUES ('409204C', '27/03/2005', '0.821'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/03/2005"
# LINE 2:                     VALUES ('219018', '27/03/2005', '-0.122'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/03/2005"
# LINE 2:                     VALUES ('409017', '27/03/2005', '2.405',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/03/2005"
# LINE 2:                     VALUES ('409204C', '28/03/2005', '0.793'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/03/2005"
# LINE 2:                     VALUES ('219018', '28/03/2005', '-0.143'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/03/2005"
# LINE 2:                     VALUES ('409017', '28/03/2005', '2.319',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/03/2005"
# LINE 2:                     VALUES ('409204C', '29/03/2005', '0.764'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/03/2005"
# LINE 2:                     VALUES ('219018', '29/03/2005', '-0.168'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/03/2005"
# LINE 2:                     VALUES ('409017', '29/03/2005', '2.312',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/03/2005"
# LINE 2:                     VALUES ('409204C', '30/03/2005', '0.734'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/03/2005"
# LINE 2:                     VALUES ('219018', '30/03/2005', '-0.195'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/03/2005"
# LINE 2:                     VALUES ('409017', '30/03/2005', '2.307',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/03/2005"
# LINE 2:                     VALUES ('409204C', '31/03/2005', '0.713'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/03/2005"
# LINE 2:                     VALUES ('219018', '31/03/2005', '-0.173'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/03/2005"
# LINE 2:                     VALUES ('409017', '31/03/2005', '2.331',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '4/04/2005', 'x', 'x', ...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '5/04/2005', 'x', 'x', ...
#                                                              ^
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('409017', '8/04/2005', 'x', 'x', ...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('409017', '9/04/2005', 'x', 'x', ...
#                                                              ^
#
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                  VALUES ('219018', '10/04/2005', 'x', 'x', ...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                  VALUES ('219018', '11/04/2005', 'x', 'x', ...
#                                                              ^
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# date/time field value out of range: "13/04/2005"
# LINE 2:                     VALUES ('409204C', '13/04/2005', '0.611'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/04/2005"
# LINE 2:                     VALUES ('219018', '13/04/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/04/2005"
# LINE 2:                     VALUES ('409017', '13/04/2005', '2.233',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/04/2005"
# LINE 2:                     VALUES ('409204C', '14/04/2005', '0.617'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/04/2005"
# LINE 2:                     VALUES ('219018', '14/04/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/04/2005"
# LINE 2:                     VALUES ('409017', '14/04/2005', '2.167',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/04/2005"
# LINE 2:                     VALUES ('409204C', '15/04/2005', '0.612'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/04/2005"
# LINE 2:                     VALUES ('219018', '15/04/2005', '0.174',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/04/2005"
# LINE 2:                     VALUES ('409017', '15/04/2005', '2.132',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/04/2005"
# LINE 2:                     VALUES ('409204C', '16/04/2005', '0.609'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/04/2005"
# LINE 2:                     VALUES ('219018', '16/04/2005', '0.173',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/04/2005"
# LINE 2:                     VALUES ('409017', '16/04/2005', '2.162',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/04/2005"
# LINE 2:                     VALUES ('409204C', '17/04/2005', '0.61',...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/04/2005"
# LINE 2:                     VALUES ('219018', '17/04/2005', '0.168',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/04/2005"
# LINE 2:                     VALUES ('409017', '17/04/2005', '2.211',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/04/2005"
# LINE 2:                     VALUES ('409204C', '18/04/2005', '0.603'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/04/2005"
# LINE 2:                     VALUES ('219018', '18/04/2005', '0.174',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/04/2005"
# LINE 2:                     VALUES ('409017', '18/04/2005', '2.208',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/04/2005"
# LINE 2:                     VALUES ('409204C', '19/04/2005', '0.593'...
# ...
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/04/2005"
# LINE 2:                     VALUES ('409204C', '21/04/2005', '0.594'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/04/2005"
# LINE 2:                     VALUES ('219018', '21/04/2005', '0.18', ...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/04/2005"
# LINE 2:                     VALUES ('409017', '21/04/2005', '2.205',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/04/2005"
# LINE 2:                     VALUES ('409204C', '22/04/2005', '0.591'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/04/2005"
# LINE 2:                     VALUES ('219018', '22/04/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/04/2005"
# LINE 2:                     VALUES ('409017', '22/04/2005', '2.247',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/04/2005"
# LINE 2:                     VALUES ('409204C', '23/04/2005', '0.58',...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/04/2005"
# LINE 2:                     VALUES ('219018', '23/04/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/04/2005"
# LINE 2:                     VALUES ('409017', '23/04/2005', '2.154',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/04/2005"
# LINE 2:                     VALUES ('409204C', '24/04/2005', '0.571'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/04/2005"
# LINE 2:                     VALUES ('219018', '24/04/2005', '0.188',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/04/2005"
# LINE 2:                     VALUES ('409017', '24/04/2005', '2.033',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/04/2005"
# LINE 2:                     VALUES ('409204C', '25/04/2005', '0.571'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/04/2005"
# LINE 2:                     VALUES ('219018', '25/04/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/04/2005"
# LINE 2:                     VALUES ('409017', '25/04/2005', '1.9', '...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/04/2005"
# LINE 2:                     VALUES ('409204C', '26/04/2005', '0.588'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/04/2005"
# LINE 2:                     VALUES ('219018', '26/04/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/04/2005"
# LINE 2:                     VALUES ('409017', '26/04/2005', '1.784',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/04/2005"
# LINE 2:                     VALUES ('409204C', '27/04/2005', '0.625'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/04/2005"
# LINE 2:                     VALUES ('219018', '27/04/2005', '0.189',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/04/2005"
# LINE 2:                     VALUES ('409017', '27/04/2005', '1.692',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/04/2005"
# LINE 2:                     VALUES ('409204C', '28/04/2005', '0.667'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/04/2005"
# LINE 2:                     VALUES ('219018', '28/04/2005', '0.188',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/04/2005"
# LINE 2:                     VALUES ('409017', '28/04/2005', '1.615',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/04/2005"
# LINE 2:                     VALUES ('409204C', '29/04/2005', '0.692'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/04/2005"
# LINE 2:                     VALUES ('219018', '29/04/2005', '0.19', ...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/04/2005"
# LINE 2:                     VALUES ('409017', '29/04/2005', '1.574',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/04/2005"
# LINE 2:                     VALUES ('409204C', '30/04/2005', '0.694'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/04/2005"
# LINE 2:                     VALUES ('219018', '30/04/2005', '0.191',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/04/2005"
# LINE 2:                     VALUES ('409017', '30/04/2005', '1.555',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '8/05/2005', 'x', 'x', ...
#                                                              ^
#
# success: row inserted
# success: row inserted
# db error:
# invalid input syntax for type double precision: "x"
# LINE 2: ...                   VALUES ('219018', '9/05/2005', 'x', 'x', ...
#                                                              ^
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# date/time field value out of range: "13/05/2005"
# LINE 2:                     VALUES ('409204C', '13/05/2005', '0.546'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/05/2005"
# LINE 2:                     VALUES ('219018', '13/05/2005', '0.193',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/05/2005"
# LINE 2:                     VALUES ('409017', '13/05/2005', '1.484',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/05/2005"
# LINE 2:                     VALUES ('409204C', '14/05/2005', '0.553'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/05/2005"
# LINE 2:                     VALUES ('219018', '14/05/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/05/2005"
# LINE 2:                     VALUES ('409017', '14/05/2005', '1.487',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/05/2005"
# LINE 2:                     VALUES ('409204C', '15/05/2005', '0.577'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/05/2005"
# LINE 2:                     VALUES ('219018', '15/05/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/05/2005"
# LINE 2:                     VALUES ('409017', '15/05/2005', '1.492',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/05/2005"
# LINE 2:                     VALUES ('409204C', '16/05/2005', '0.604'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/05/2005"
# LINE 2:                     VALUES ('219018', '16/05/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/05/2005"
# LINE 2:                     VALUES ('409017', '16/05/2005', '1.471',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/05/2005"
# LINE 2:                     VALUES ('409204C', '17/05/2005', '0.66',...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/05/2005"
# LINE 2:                     VALUES ('219018', '17/05/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/05/2005"
# LINE 2:                     VALUES ('409017', '17/05/2005', '1.537',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/05/2005"
# LINE 2:                     VALUES ('409204C', '18/05/2005', '0.705'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/05/2005"
# LINE 2:                     VALUES ('219018', '18/05/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/05/2005"
# LINE 2:                     VALUES ('409017', '18/05/2005', '1.597',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/05/2005"
# LINE 2:                     VALUES ('409204C', '19/05/2005', '0.713'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/05/2005"
# LINE 2:                     VALUES ('219018', '19/05/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/05/2005"
# LINE 2:                     VALUES ('409017', '19/05/2005', '1.489',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/05/2005"
# LINE 2:                     VALUES ('409204C', '20/05/2005', '0.716'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/05/2005"
# LINE 2:                     VALUES ('219018', '20/05/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/05/2005"
# LINE 2:                     VALUES ('409017', '20/05/2005', '1.48', ...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/05/2005"
# LINE 2:                     VALUES ('409204C', '21/05/2005', '0.731'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/05/2005"
# LINE 2:                     VALUES ('219018', '21/05/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/05/2005"
# LINE 2:                     VALUES ('409017', '21/05/2005', '1.488',...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/05/2005"
# LINE 2:                     VALUES ('409204C', '22/05/2005', '0.756'...
#                                                ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/05/2005"
# LINE 2:                     VALUES ('409017', '22/05/2005', '1.5', '...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/05/2005"
# LINE 2:                     VALUES ('409017', '23/05/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/05/2005"
# LINE 2:                     VALUES ('409017', '24/05/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/05/2005"
# LINE 2:                     VALUES ('409017', '25/05/2005', 'x', 'x'...
#                                               ^
# HINT:  Perhaps you need a different "datestyle" setting.

# %% [markdown]
# # STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.

# %% [markdown]
# ## EXERCISE 2: Data Cleaning
#
# ### Data Cleaning
# We re-use the clean() function.

# %%
import numpy as np
DEFAULT_VALUE = np.nan

def clean(data, column_key, convert_function, default_value):
    special_values= {} # no special values yet
    for row in data:
        old_value = row[column_key]
        new_value = default_value
        try:
            if old_value in special_values.keys():
                new_value = special_values[old_value]
            else:
                new_value = convert_function(old_value)
        except (ValueError, TypeError):
            print('Replacing {} with {} in column {}'.format(row[column_key], new_value, column_key))
        row[column_key] = new_value

# %%
# this conversion strips any leading or trailing spaces from the 'Station' values
clean(data_measurements, 'Station', str.strip, DEFAULT_VALUE)

# the following converts the two measurment  columns to float  values - or NaN
clean(data_measurements, 'Discharge', float, DEFAULT_VALUE)
clean(data_measurements, 'MeanDischarge', float, DEFAULT_VALUE)
clean(data_measurements, 'Level', float, DEFAULT_VALUE)
clean(data_measurements, 'Temp', float, DEFAULT_VALUE)
clean(data_measurements, 'EC', float, DEFAULT_VALUE)

##now we insert the  data_measurements into the 'Measurement' table 
# 1st: login to database
if(conn):
    conn.close();
conn = pgconnect()

# 2nd: ensure that the schema is in place
pgexec (conn, "DROP TABLE IF EXISTS Measurement", None, "Reset Table Measurement")
measurement_schema = """CREATE TABLE IF NOT EXISTS Measurement (
                         station   VARCHAR(20),
                         date DATE,
                         level  FLOAT,
                         meanDischarge FLOAT,
                         discharge  FLOAT,
                         temp FLOAT,
                         ec  FLOAT
                      )"""
pgexec (conn, measurement_schema, None, "Create Table Measurement")

# 3nd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Measurement(station,date,level,meandischarge,discharge,temp,ec)
                      VALUES (%(Station)s, %(Date)s, %(Level)s,%(MeanDischarge)s,%(Discharge)s,%(Temp)s,%(EC)s)"""
for row in data_measurements:
    pgexec (conn, insert_stmt, row, "row inserted")
    
query_stmt = "SELECT COUNT(*) FROM Measurement"
print(query_stmt)
pgquery (conn, query_stmt, None)
# Out:
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# connected
# success: Reset Table Measurement
# success: Create Table Measurement
# db error:
# date/time field value out of range: "31/12/2004"
# LINE 2:                       VALUES ('409204C', '31/12/2004', 1.196...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/12/2004"
# LINE 2:                       VALUES ('219018', '31/12/2004', 0.219,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/12/2004"
# LINE 2:                       VALUES ('409017', '31/12/2004', 2.552,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# date/time field value out of range: "13/01/2005"
# LINE 2:                       VALUES ('409204C', '13/01/2005', 1.043...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/01/2005"
# LINE 2:                       VALUES ('219018', '13/01/2005', 0.179,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/01/2005"
# LINE 2:                       VALUES ('409017', '13/01/2005', 2.586,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/01/2005"
# LINE 2:                       VALUES ('409204C', '14/01/2005', 1.036...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/01/2005"
# LINE 2:                       VALUES ('219018', '14/01/2005', 0.167,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/01/2005"
# LINE 2:                       VALUES ('409017', '14/01/2005', 2.593,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/01/2005"
# LINE 2:                       VALUES ('409204C', '15/01/2005', 1.018...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/01/2005"
# LINE 2:                       VALUES ('219018', '15/01/2005', 0.154,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/01/2005"
# LINE 2:                       VALUES ('409017', '15/01/2005', 2.607,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/01/2005"
# LINE 2:                       VALUES ('409204C', '16/01/2005', 0.995...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/01/2005"
# LINE 2:                       VALUES ('219018', '16/01/2005', 0.115,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/01/2005"
# LINE 2:                       VALUES ('409017', '16/01/2005', 2.65,1...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/01/2005"
# LINE 2:                       VALUES ('409204C', '17/01/2005', 0.976...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/01/2005"
# LINE 2:                       VALUES ('219018', '17/01/2005', 0.078,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/01/2005"
# LINE 2:                       VALUES ('409017', '17/01/2005', 2.622,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/01/2005"
# LINE 2:                       VALUES ('409204C', '18/01/2005', 0.951...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/01/2005"
# LINE 2:                       VALUES ('219018', '18/01/2005', 0.047,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/01/2005"
# LINE 2:                       VALUES ('409017', '18/01/2005', 2.638,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/01/2005"
# LINE 2:                       VALUES ('409204C', '19/01/2005', 0.918...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/01/2005"
# LINE 2:                       VALUES ('219018', '19/01/2005', 0.013,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/01/2005"
# LINE 2:                       VALUES ('409017', '19/01/2005', 2.634,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/01/2005"
# LINE 2:                       VALUES ('409204C', '20/01/2005', 0.896...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/01/2005"
# LINE 2:                       VALUES ('219018', '20/01/2005',  -0.01...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/01/2005"
# LINE 2:                       VALUES ('409017', '20/01/2005', 2.672,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/01/2005"
# LINE 2:                       VALUES ('409204C', '21/01/2005', 0.894...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/01/2005"
# LINE 2:                       VALUES ('219018', '21/01/2005',  -0.03...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/01/2005"
# LINE 2:                       VALUES ('409017', '21/01/2005', 2.718,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/01/2005"
# LINE 2:                       VALUES ('409204C', '22/01/2005', 0.89,...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/01/2005"
# LINE 2:                       VALUES ('219018', '22/01/2005',  -0.00...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/01/2005"
# LINE 2:                       VALUES ('409017', '22/01/2005', 2.741,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/01/2005"
# LINE 2:                       VALUES ('409204C', '23/01/2005', 0.878...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/01/2005"
# LINE 2:                       VALUES ('219018', '23/01/2005',  -0.02...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/01/2005"
# LINE 2:                       VALUES ('409017', '23/01/2005', 2.701,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/01/2005"
# LINE 2:                       VALUES ('409204C', '24/01/2005', 0.881...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/01/2005"
# LINE 2:                       VALUES ('219018', '24/01/2005',  -0.06...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/01/2005"
# LINE 2:                       VALUES ('409017', '24/01/2005', 2.653,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/01/2005"
# LINE 2:                       VALUES ('409204C', '25/01/2005', 0.888...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/01/2005"
# LINE 2:                       VALUES ('219018', '25/01/2005',  -0.11...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/01/2005"
# LINE 2:                       VALUES ('409017', '25/01/2005', 2.65,1...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/01/2005"
# LINE 2:                       VALUES ('409204C', '26/01/2005', 0.909...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/01/2005"
# LINE 2:                       VALUES ('219018', '26/01/2005',  -0.16...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/01/2005"
# LINE 2:                       VALUES ('409017', '26/01/2005', 2.688,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/01/2005"
# LINE 2:                       VALUES ('409204C', '27/01/2005', 0.923...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/01/2005"
# LINE 2:                       VALUES ('219018', '27/01/2005',  -0.22...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/01/2005"
# LINE 2:                       VALUES ('409017', '27/01/2005', 2.725,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/01/2005"
# LINE 2:                       VALUES ('409204C', '28/01/2005', 0.937...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/01/2005"
# LINE 2:                       VALUES ('219018', '28/01/2005',  -0.24...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/01/2005"
# LINE 2:                       VALUES ('409017', '28/01/2005', 2.717,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/01/2005"
# LINE 2:                       VALUES ('409204C', '29/01/2005', 0.956...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/01/2005"
# LINE 2:                       VALUES ('219018', '29/01/2005',  -0.24...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/01/2005"
# LINE 2:                       VALUES ('409017', '29/01/2005', 2.741,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/01/2005"
# LINE 2:                       VALUES ('409204C', '30/01/2005', 0.981...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/01/2005"
# LINE 2:                       VALUES ('219018', '30/01/2005',  -0.24...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/01/2005"
# LINE 2:                       VALUES ('409017', '30/01/2005', 2.814,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/01/2005"
# LINE 2:                       VALUES ('409204C', '31/01/2005', 1.001...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/01/2005"
# LINE 2:                       VALUES ('219018', '31/01/2005',  -0.24...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "31/01/2005"
# LINE 2:                       VALUES ('409017', '31/01/2005', 2.814,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# date/time field value out of range: "13/02/2005"
# LINE 2:                       VALUES ('409204C', '13/02/2005', 1.128...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/02/2005"
# LINE 2:                       VALUES ('219018', '13/02/2005',  -0.24...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/02/2005"
# LINE 2:                       VALUES ('409017', '13/02/2005', 2.774,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/02/2005"
# LINE 2:                       VALUES ('409204C', '14/02/2005', 1.138...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/02/2005"
# LINE 2:                       VALUES ('219018', '14/02/2005',  -0.24...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/02/2005"
# LINE 2:                       VALUES ('409017', '14/02/2005', 2.699,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/02/2005"
# LINE 2:                       VALUES ('409204C', '15/02/2005', 1.146...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/02/2005"
# LINE 2:                       VALUES ('219018', '15/02/2005',  -0.24...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/02/2005"
# LINE 2:                       VALUES ('409017', '15/02/2005', 2.7,11...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/02/2005"
# LINE 2:                       VALUES ('409204C', '16/02/2005', 1.149...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/02/2005"
# LINE 2:                       VALUES ('219018', '16/02/2005',  -0.24...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/02/2005"
# LINE 2:                       VALUES ('409017', '16/02/2005', 2.721,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/02/2005"
# LINE 2:                       VALUES ('409204C', '17/02/2005', 1.157...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/02/2005"
# LINE 2:                       VALUES ('219018', '17/02/2005',  -0.20...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/02/2005"
# LINE 2:                       VALUES ('409017', '17/02/2005', 2.72,1...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/02/2005"
# LINE 2:                       VALUES ('409204C', '18/02/2005', 1.172...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/02/2005"
# LINE 2:                       VALUES ('219018', '18/02/2005',  -0.15...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/02/2005"
# LINE 2:                       VALUES ('409017', '18/02/2005', 2.696,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/02/2005"
# LINE 2:                       VALUES ('409204C', '19/02/2005', 1.183...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/02/2005"
# LINE 2:                       VALUES ('219018', '19/02/2005',  -0.09...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/02/2005"
# LINE 2:                       VALUES ('409017', '19/02/2005', 2.681,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/02/2005"
# LINE 2:                       VALUES ('409204C', '20/02/2005', 1.187...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/02/2005"
# LINE 2:                       VALUES ('219018', '20/02/2005',  -0.06...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/02/2005"
# LINE 2:                       VALUES ('409017', '20/02/2005', 2.694,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/02/2005"
# LINE 2:                       VALUES ('409204C', '21/02/2005', 1.192...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/02/2005"
# LINE 2:                       VALUES ('219018', '21/02/2005',  -0.02...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/02/2005"
# LINE 2:                       VALUES ('409017', '21/02/2005', 2.722,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/02/2005"
# LINE 2:                       VALUES ('409204C', '22/02/2005', 1.198...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/02/2005"
# LINE 2:                       VALUES ('219018', '22/02/2005', 0.021,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/02/2005"
# LINE 2:                       VALUES ('409017', '22/02/2005', 2.72,1...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/02/2005"
# LINE 2:                       VALUES ('409204C', '23/02/2005', 1.202...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/02/2005"
# LINE 2:                       VALUES ('219018', '23/02/2005', 0.046,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/02/2005"
# LINE 2:                       VALUES ('409017', '23/02/2005', 2.721,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/02/2005"
# LINE 2:                       VALUES ('409204C', '24/02/2005', 1.206...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/02/2005"
# LINE 2:                       VALUES ('219018', '24/02/2005', 0.053,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/02/2005"
# LINE 2:                       VALUES ('409017', '24/02/2005', 2.721,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/02/2005"
# LINE 2:                       VALUES ('409204C', '25/02/2005', 1.223...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/02/2005"
# LINE 2:                       VALUES ('219018', '25/02/2005', 0.055,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/02/2005"
# LINE 2:                       VALUES ('409017', '25/02/2005', 2.723,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/02/2005"
# LINE 2:                       VALUES ('409204C', '26/02/2005', 1.234...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/02/2005"
# LINE 2:                       VALUES ('219018', '26/02/2005', 0.045,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/02/2005"
# LINE 2:                       VALUES ('409017', '26/02/2005', 2.728,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/02/2005"
# LINE 2:                       VALUES ('409204C', '27/02/2005', 1.24,...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/02/2005"
# LINE 2:                       VALUES ('219018', '27/02/2005', 0.033,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/02/2005"
# LINE 2:                       VALUES ('409017', '27/02/2005', 2.714,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/02/2005"
# LINE 2:                       VALUES ('409204C', '28/02/2005', 1.239...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/02/2005"
# LINE 2:                       VALUES ('219018', '28/02/2005', 0.017,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/02/2005"
# LINE 2:                       VALUES ('409017', '28/02/2005', 2.684,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# date/time field value out of range: "13/03/2005"
# LINE 2:                       VALUES ('409204C', '13/03/2005', 1.186...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/03/2005"
# LINE 2:                       VALUES ('219018', '13/03/2005', 0.052,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/03/2005"
# LINE 2:                       VALUES ('409017', '13/03/2005', 2.626,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/03/2005"
# LINE 2:                       VALUES ('409204C', '14/03/2005', 1.169...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/03/2005"
# LINE 2:                       VALUES ('219018', '14/03/2005', 0.067,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/03/2005"
# LINE 2:                       VALUES ('409017', '14/03/2005', 2.6,10...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/03/2005"
# LINE 2:                       VALUES ('409204C', '15/03/2005', 1.146...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/03/2005"
# LINE 2:                       VALUES ('219018', '15/03/2005', 0.104,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/03/2005"
# LINE 2:                       VALUES ('409017', '15/03/2005', 2.589,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/03/2005"
# LINE 2:                       VALUES ('409204C', '16/03/2005', 1.127...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/03/2005"
# LINE 2:                       VALUES ('219018', '16/03/2005', 0.119,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/03/2005"
# LINE 2:                       VALUES ('409017', '16/03/2005', 2.581,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/03/2005"
# LINE 2:                       VALUES ('409204C', '17/03/2005', 1.106...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/03/2005"
# LINE 2:                       VALUES ('219018', '17/03/2005', 0.117,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/03/2005"
# LINE 2:                       VALUES ('409017', '17/03/2005', 2.559,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/03/2005"
# LINE 2:                       VALUES ('409204C', '18/03/2005', 1.078...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/03/2005"
# LINE 2:                       VALUES ('219018', '18/03/2005', 0.102,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/03/2005"
# LINE 2:                       VALUES ('409017', '18/03/2005', 2.496,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/03/2005"
# LINE 2:                       VALUES ('409204C', '19/03/2005', 1.056...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/03/2005"
# LINE 2:                       VALUES ('219018', '19/03/2005', 0.082,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/03/2005"
# LINE 2:                       VALUES ('409017', '19/03/2005', 2.44,8...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/03/2005"
# LINE 2:                       VALUES ('409204C', '20/03/2005', 1.028...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/03/2005"
# LINE 2:                       VALUES ('219018', '20/03/2005', 0.053,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/03/2005"
# LINE 2:                       VALUES ('409017', '20/03/2005', 2.459,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/03/2005"
# LINE 2:                       VALUES ('409204C', '21/03/2005', 0.997...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/03/2005"
# LINE 2:                       VALUES ('219018', '21/03/2005', 0.024,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/03/2005"
# LINE 2:                       VALUES ('409017', '21/03/2005', 2.452,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# ...
#
# db error:
# date/time field value out of range: "20/04/2005"
# LINE 2:                       VALUES ('409017', '20/04/2005', 2.192,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/04/2005"
# LINE 2:                       VALUES ('409204C', '21/04/2005', 0.594...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/04/2005"
# LINE 2:                       VALUES ('219018', '21/04/2005', 0.18,0...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/04/2005"
# LINE 2:                       VALUES ('409017', '21/04/2005', 2.205,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/04/2005"
# LINE 2:                       VALUES ('409204C', '22/04/2005', 0.591...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/04/2005"
# LINE 2:                       VALUES ('219018', '22/04/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/04/2005"
# LINE 2:                       VALUES ('409017', '22/04/2005', 2.247,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/04/2005"
# LINE 2:                       VALUES ('409204C', '23/04/2005', 0.58,...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/04/2005"
# LINE 2:                       VALUES ('219018', '23/04/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/04/2005"
# LINE 2:                       VALUES ('409017', '23/04/2005', 2.154,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/04/2005"
# LINE 2:                       VALUES ('409204C', '24/04/2005', 0.571...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/04/2005"
# LINE 2:                       VALUES ('219018', '24/04/2005', 0.188,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/04/2005"
# LINE 2:                       VALUES ('409017', '24/04/2005', 2.033,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/04/2005"
# LINE 2:                       VALUES ('409204C', '25/04/2005', 0.571...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/04/2005"
# LINE 2:                       VALUES ('219018', '25/04/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/04/2005"
# LINE 2:                       VALUES ('409017', '25/04/2005', 1.9,33...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/04/2005"
# LINE 2:                       VALUES ('409204C', '26/04/2005', 0.588...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/04/2005"
# LINE 2:                       VALUES ('219018', '26/04/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "26/04/2005"
# LINE 2:                       VALUES ('409017', '26/04/2005', 1.784,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/04/2005"
# LINE 2:                       VALUES ('409204C', '27/04/2005', 0.625...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/04/2005"
# LINE 2:                       VALUES ('219018', '27/04/2005', 0.189,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "27/04/2005"
# LINE 2:                       VALUES ('409017', '27/04/2005', 1.692,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/04/2005"
# LINE 2:                       VALUES ('409204C', '28/04/2005', 0.667...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/04/2005"
# LINE 2:                       VALUES ('219018', '28/04/2005', 0.188,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "28/04/2005"
# LINE 2:                       VALUES ('409017', '28/04/2005', 1.615,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/04/2005"
# LINE 2:                       VALUES ('409204C', '29/04/2005', 0.692...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/04/2005"
# LINE 2:                       VALUES ('219018', '29/04/2005', 0.19,0...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "29/04/2005"
# LINE 2:                       VALUES ('409017', '29/04/2005', 1.574,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/04/2005"
# LINE 2:                       VALUES ('409204C', '30/04/2005', 0.694...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/04/2005"
# LINE 2:                       VALUES ('219018', '30/04/2005', 0.191,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "30/04/2005"
# LINE 2:                       VALUES ('409017', '30/04/2005', 1.555,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# date/time field value out of range: "13/05/2005"
# LINE 2:                       VALUES ('409204C', '13/05/2005', 0.546...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/05/2005"
# LINE 2:                       VALUES ('219018', '13/05/2005', 0.193,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "13/05/2005"
# LINE 2:                       VALUES ('409017', '13/05/2005', 1.484,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/05/2005"
# LINE 2:                       VALUES ('409204C', '14/05/2005', 0.553...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/05/2005"
# LINE 2:                       VALUES ('219018', '14/05/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "14/05/2005"
# LINE 2:                       VALUES ('409017', '14/05/2005', 1.487,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/05/2005"
# LINE 2:                       VALUES ('409204C', '15/05/2005', 0.577...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/05/2005"
# LINE 2:                       VALUES ('219018', '15/05/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "15/05/2005"
# LINE 2:                       VALUES ('409017', '15/05/2005', 1.492,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/05/2005"
# LINE 2:                       VALUES ('409204C', '16/05/2005', 0.604...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/05/2005"
# LINE 2:                       VALUES ('219018', '16/05/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "16/05/2005"
# LINE 2:                       VALUES ('409017', '16/05/2005', 1.471,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/05/2005"
# LINE 2:                       VALUES ('409204C', '17/05/2005', 0.66,...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/05/2005"
# LINE 2:                       VALUES ('219018', '17/05/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "17/05/2005"
# LINE 2:                       VALUES ('409017', '17/05/2005', 1.537,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/05/2005"
# LINE 2:                       VALUES ('409204C', '18/05/2005', 0.705...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/05/2005"
# LINE 2:                       VALUES ('219018', '18/05/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "18/05/2005"
# LINE 2:                       VALUES ('409017', '18/05/2005', 1.597,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/05/2005"
# LINE 2:                       VALUES ('409204C', '19/05/2005', 0.713...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/05/2005"
# LINE 2:                       VALUES ('219018', '19/05/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "19/05/2005"
# LINE 2:                       VALUES ('409017', '19/05/2005', 1.489,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/05/2005"
# LINE 2:                       VALUES ('409204C', '20/05/2005', 0.716...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/05/2005"
# LINE 2:                       VALUES ('219018', '20/05/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "20/05/2005"
# LINE 2:                       VALUES ('409017', '20/05/2005', 1.48,1...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/05/2005"
# LINE 2:                       VALUES ('409204C', '21/05/2005', 0.731...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/05/2005"
# LINE 2:                       VALUES ('219018', '21/05/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "21/05/2005"
# LINE 2:                       VALUES ('409017', '21/05/2005', 1.488,...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/05/2005"
# LINE 2:                       VALUES ('409204C', '22/05/2005', 0.756...
#                                                  ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "22/05/2005"
# LINE 2:                       VALUES ('409017', '22/05/2005', 1.5,12...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "23/05/2005"
# LINE 2:                       VALUES ('409017', '23/05/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "24/05/2005"
# LINE 2:                       VALUES ('409017', '24/05/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# db error:
# date/time field value out of range: "25/05/2005"
# LINE 2:                       VALUES ('409017', '25/05/2005', 'NaN':...
#                                                 ^
# HINT:  Perhaps you need a different "datestyle" setting.
#
# SELECT COUNT(*) FROM Measurement
# (180,)
# True

# %% [markdown]
# ## Your Task: Data Cleaning
#
# Use above's  clean()  function to clean the other give data set too.
#  1. read the Stations csv file into data_stations
#  2. Clean the  'data_stations'  data set
#  3. Reload the 'data_stations'  dictionary into your database
#  4. Query the 'Stations' table - which difference do you see?
#
#  5. If you have time: Do all of the above (reading - cleaning - loading) also for the 'Sensors.csv' data set

# %% [markdown]
# Note: You might encounter a few warning and error messages.
#    - If a connection is closed, you have to open the databse connection again first
#    - If the clean() function returns a warning that some string was replaced with NaN, as long as this is indeed a number attribute, you are Ok to ignore this message. It just tells you that it is doing what it is supposed to do.
#    - If you try to insert data into an already existing table with data inside, you might get 'duplicate primary key' error messages. Again, you can ignore those for the moment.
#    - If you want to see who much data is already in your table, use the following SQL query:
#      -  SELECT COUNT(*) FROM Stations;

# %%
# TODO: replace the content of this cell with your Python solution
data_stations = list(csv.DictReader(open('Stations.csv')))
pprint.pprint(data_stations[0])

# if you want to reset the table
pgexec(conn, "DROP TABLE IF EXISTS Station", None, "Reset Table Station")
# 2nd: ensure that the schema is in place
stations_schema = """CREATE TABLE IF NOT EXISTS Station (
                        station VARCHAR(20) PRIMARY KEY, 
                        siteName VARCHAR(150), 
                        commence DATE, 
                        orgCode VARCHAR(20)
                )"""
pgexec(conn, stations_schema, None, "Create Table Station")
pgexec(conn, "SET datestyle = 'ISO,DMY'; ", None, "Modify datestyle")

# 3rd load data
# IMPORTANT: make sure the header line of csv is without spaces! 
insert_stmt = """INSERT INTO Station(station, siteName, commence, orgCode)
                    VALUES (%(Station)s, %(SiteName)s, %(Commence)s, %(OrgCode)s)"""

stationData = dict()
for row in data_stations: 
    stationData['Station'] = row['BasinNo'] + row['Site']
    stationData['SiteName'] = row['SiteName']
    stationData['Commence'] = row['Commence']
    stationData['OrgCode'] = row['OrgCode']
    
    pgexec(conn, insert_stmt, stationData, "row inserted")
    
query_stmt = "SELECT COUNT(*) FROM Station"
print(query_stmt)
pgquery(conn, query_stmt, None)
# Out:
# {'BasinNo': '409',
#  'Commence': '14/04/1892',
#  'Lat': '36.0929 S',
#  'Long': '146.8957 E',
#  'OrgCode': 'DWR',
#  'Site': '001',
#  'SiteName': 'Murray River at Albury (Union Bridge)'}
# success: Reset Table Station
# success: Create Table Station
# success: Modify datestyle
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# SELECT COUNT(*) FROM Station
# (9,)
# True

# %% [markdown]
# # STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.

# %% [markdown]
# ## EXERCISE 3: Database Creation
# After we discussed the model, we will give you an example solution (see below).
# The next step is to create the corresponding SQL schema in your PostgreSQL database.
#
# ### Your Task: DB Creation in PostgreSQL
# Create the corresponding tables in PostgreSQL which follow from the data model.

# %% [markdown]
# <pre>
# DROP TABLE IF EXISTS Organisation CASCADE;
# CREATE TABLE IF NOT EXISTS Organisation (
#    code VARCHAR(20) PRIMARY KEY,
#    organisation    VARCHAR(150)
# );
#
# DROP TABLE IF EXISTS Station CASCADE;
# CREATE TABLE IF NOT EXISTS Station (
#      station   VARCHAR(50) PRIMARY KEY,
#      siteName  VARCHAR(50),
#      commence Date,
#      orgCode  VARCHAR(50),
#      CONSTRAINT orgCodeFK FOREIGN KEY (orgCode)   REFERENCES Organisation (code)
#  );
#
# DROP TABLE IF EXISTS Sensor CASCADE;
# CREATE TABLE IF NOT EXISTS Sensor (
#      sensor   VARCHAR(20) PRIMARY KEY,
#      description  VARCHAR(150) ,
#      metric VARCHAR(20)
#   );
#
# DROP TABLE IF EXISTS Measurement CASCADE;
# CREATE TABLE IF NOT EXISTS Measurement (
#      station   VARCHAR(20),
#      sensor   VARCHAR(20),
#      date DATE,
#      value  FLOAT,
#      CONSTRAINT stationFK FOREIGN KEY (station)   REFERENCES Station (Station),
#      CONSTRAINT sensorFK FOREIGN KEY (sensor)   REFERENCES sensor (sensor)
#   );
#
# </pre>

# %%
# TODO: replace the content of this cell with your Python + SQL solution
# make sure we are still connected to database 
table_schema = """
DROP TABLE IF EXISTS Organisation CASCADE; 
CREATE TABLE IF NOT EXISTS Organisation (
    code VARCHAR(20) PRIMARY KEY, 
    organisation VARCHAR(150)
);

DROP TABLE IF EXISTS Station CASCADE;
CREATE TABLE IF NOT EXISTS Station ( 
    station VARCHAR(50) PRIMARY KEY,
    siteName VARCHAR(50), 
    commence Date, 
    orgCode VARCHAR(50), 
    CONSTRAINT orgCodeFK FOREIGN KEY (orgCode) REFERENCES Organisation
);

DROP TABLE IF EXISTS Sensor CASCADE; 
CREATE TABLE IF NOT EXISTS Sensor ( 
    sensor VARCHAR(20) PRIMARY KEY, 
    description VARCHAR(150), 
    metric VARCHAR(20)
);

DROP TABLE IF EXISTS Measurement CASCADE; 
CREATE TABLE IF NOT EXISTS Measurement (
    station VARCHAR(20), 
    sensor VARCHAR(20), 
    date DATE, 
    value FLOAT, 
    CONSTRAINT stationFK FOREIGN KEY (station) REFERENCES Station (Station), 
    CONSTRAINT sensorFK FOREIGN KEY (sensor) REFERENCES sensor (sensor)
);
"""

conn = pgconnect()
pgexec(conn, table_schema, None, "Created our data warehouse")
pgexec(conn, "SET datestyle = 'ISO,DMY'; ", None, "Modify datestyle")
# Out:
# connected
# success: Created our data warehouse
# success: Modify datestyle
# True

# %% [markdown]
# # STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.

# %% [markdown]
# ## EXERCISE 4: Data Loading and Storage
#
# Up-to this point, we have
#  - analysed and modelled the given data set
#  - created a corresponding relational star schema
#  - read the individual CSV files into Python dictionary data structures
#  - cleaned the raw data with regard to missing or inconsistent entries and data types
#
# The final step is to load this cleaned data into the corresponding tables of the star schema which we defined so far.
#
# For this to work, you probably will need to write some logic to load different parts of different data dictionaries (holding the content of CSV files) into different tables.

# %%
import numpy as np
import csv
import pprint
# Organisation table
data_organisations = list(csv.DictReader(open('Organisations.csv')))

# make sure we are still connected to database 
if conn is None or conn.closed:
    conn = pgconnect()

# check for any existing content of the Organisations table
query_stmt = "SELECT COUNT(*) FROM Organisation"
print(query_stmt)
pgquery (conn, query_stmt, None)

# Try to load data - 9 tupels should be created
insert_stmt = """INSERT INTO Organisation(code,organisation) VALUES (%(Code)s, %(Organisation)s)"""
for row in data_organisations:
    pgexec (conn, insert_stmt, row, "row inserted")
    
#####################
# Station table    
data_stations = list(csv.DictReader(open('Stations.csv')))

# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Station(station,siteName,commence,orgCode)
                      VALUES (%(station)s, %(siteName)s, %(commence)s,%(orgCode)s)"""
stationData = dict()
for row in data_stations:
    stationData['station'] = row['BasinNo']+row['Site']
    stationData['siteName']  = row['SiteName']
    stationData['commence'] = row['Commence']
    stationData['orgCode'] = row['OrgCode']
    pgexec (conn, insert_stmt, stationData, "station inserted")

# check content of Station table
query_stmt = "SELECT * FROM Station"
print(query_stmt)
pgquery (conn, query_stmt, None)



#####################
# Sensor table    
data_sensors = list(csv.DictReader(open('Sensors.csv')))

# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Sensor(sensor,description,metric)
                      VALUES (%(sensor)s, %(description)s, %(metric)s)"""

for row in data_sensors:
    pgexec (conn, insert_stmt, row, "sensor inserted")

# check content of Station table
query_stmt = "SELECT * FROM Sensor"
print(query_stmt)
pgquery (conn, query_stmt, None)


#####################
# Measurement table    
data_measurements = list(csv.DictReader(open('Measurements.csv')))

# the following converts the two measurment  columns to float  values - or NaN
clean(data_measurements, 'Discharge', float, DEFAULT_VALUE)
clean(data_measurements, 'MeanDischarge', float, DEFAULT_VALUE)
clean(data_measurements, 'Level', float, DEFAULT_VALUE)
clean(data_measurements, 'Temp', float, DEFAULT_VALUE)
clean(data_measurements, 'EC', float, DEFAULT_VALUE)

# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Measurement(station,date,sensor,value)
                      VALUES (%(station)s, %(date)s, %(sensor)s, %(value)s)"""

measurementData = dict()
sensorCodes = ['levl', 'disvol','disc','temp', 'ec']
sensor_columns = ['Level', 'MeanDischarge', 'Discharge','Temp', 'EC']
for row in data_measurements:
    measurementData['station'] = row['Station']
    measurementData['date'] = row['Date']
    for i in range(len(sensorCodes)):
        if(np.isnan(row[sensor_columns[i]])):
            continue;
        measurementData['sensor'] = sensorCodes[i]
        measurementData['value']  = row[sensor_columns[i]]
        pgexec (conn, insert_stmt, measurementData, "measurement inserted")
    

# check content of Measurement table
query_stmt = "SELECT * FROM Measurement"
print(query_stmt)
pgquery (conn, query_stmt, None)

query_stmt = "SELECT count(*) FROM Measurement"
print(query_stmt)
pgquery (conn, query_stmt, None)
conn.close();
# Out:
# SELECT COUNT(*) FROM Organisation
# (0,)
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# success: station inserted
# SELECT * FROM Station
# ('409001', 'Murray River at Albury (Union Bridge)', datetime.date(1892, 4, 14), 'DWR')
# ('409002', 'Murray River at Corowa', datetime.date(1894, 4, 1), 'DWR')
# ('409003', 'Murray River at Denuquin', datetime.date(1896, 9, 1), 'DWR')
# ('409005', 'Murray River at Barham', datetime.date(1900, 12, 31), 'DWR')
# ('409204C', 'Murray River @ Swan Hill', datetime.date(1904, 12, 31), 'VRW')
# ('409017', 'Murray River @ Doctors Point', datetime.date(1925, 8, 22), 'DWR')
# ('409019', 'Wakool River at Offtake Regulator', datetime.date(1931, 2, 7), 'DWR')
# ('409202', 'Murray River @ Tocumwal', datetime.date(1886, 6, 6), 'VRW')
# ('219018', 'Murray River @ Quaama', datetime.date(1962, 11, 7), 'DWR')
# success: sensor inserted
# success: sensor inserted
# success: sensor inserted
# success: sensor inserted
# success: sensor inserted
# success: sensor inserted
# success: sensor inserted
# SELECT * FROM Sensor
# ('levl', 'Level - Stream Water (Gauge Height)', 'meter')
# ('temp', 'Water Temperature', 'celsius')
# ('disc', 'Discharge Rate', 'ML/d')
# ('disvol', 'Discharge Volume', 'ML')
# ('ph', 'pH Value', 'pH')
# ('ec25', 'Electrical Conductivity @25 C', 'us/cm')
# ('ec', 'Electrical Conductivity (uncorrected)', 'us/cm')
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Discharge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Level
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column Temp
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# Replacing x with nan in column EC
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# success: measurement inserted
# ...
# ('219018', 'levl', datetime.date(2005, 4, 28), 0.188)
# ('219018', 'disvol', datetime.date(2005, 4, 28), 0.612)
# ('219018', 'disc', datetime.date(2005, 4, 28), 0.625)
# ('409017', 'levl', datetime.date(2005, 4, 28), 1.615)
# ('409017', 'disvol', datetime.date(2005, 4, 28), 1758.802)
# ('409017', 'disc', datetime.date(2005, 4, 28), 1676.276)
# ('409017', 'temp', datetime.date(2005, 4, 28), 13.436)
# ('409017', 'ec', datetime.date(2005, 4, 28), 40.844)
# ('409204C', 'levl', datetime.date(2005, 4, 29), 0.692)
# ('409204C', 'disvol', datetime.date(2005, 4, 29), 2689.099)
# ('409204C', 'disc', datetime.date(2005, 4, 29), 2724.934)
# ('409204C', 'temp', datetime.date(2005, 4, 29), 14.317)
# ('409204C', 'ec', datetime.date(2005, 4, 29), 41.25)
# ('219018', 'levl', datetime.date(2005, 4, 29), 0.19)
# ('219018', 'disvol', datetime.date(2005, 4, 29), 0.658)
# ('219018', 'disc', datetime.date(2005, 4, 29), 0.703)
# ('409017', 'levl', datetime.date(2005, 4, 29), 1.574)
# ('409017', 'disvol', datetime.date(2005, 4, 29), 1577.205)
# ('409017', 'disc', datetime.date(2005, 4, 29), 1509.18)
# ('409017', 'temp', datetime.date(2005, 4, 29), 12.341)
# ('409017', 'ec', datetime.date(2005, 4, 29), 37.0)
# ('409204C', 'levl', datetime.date(2005, 4, 30), 0.694)
# ('409204C', 'disvol', datetime.date(2005, 4, 30), 2698.293)
# ('409204C', 'disc', datetime.date(2005, 4, 30), 2709.609)
# ('409204C', 'temp', datetime.date(2005, 4, 30), 14.056)
# ('409204C', 'ec', datetime.date(2005, 4, 30), 39.042)
# ('219018', 'levl', datetime.date(2005, 4, 30), 0.191)
# ('219018', 'disvol', datetime.date(2005, 4, 30), 0.697)
# ('219018', 'disc', datetime.date(2005, 4, 30), 0.655)
# ('409017', 'levl', datetime.date(2005, 4, 30), 1.555)
# ('409017', 'disvol', datetime.date(2005, 4, 30), 1495.291)
# ('409017', 'disc', datetime.date(2005, 4, 30), 1356.156)
# ('409017', 'temp', datetime.date(2005, 4, 30), 11.939)
# ('409017', 'ec', datetime.date(2005, 4, 30), 32.401)
# ('409204C', 'levl', datetime.date(2005, 5, 1), 0.694)
# ('409204C', 'disvol', datetime.date(2005, 5, 1), 2697.464)
# ('409204C', 'disc', datetime.date(2005, 5, 1), 2699.206)
# ('409204C', 'temp', datetime.date(2005, 5, 1), 14.35)
# ('409204C', 'ec', datetime.date(2005, 5, 1), 39.917)
# ('219018', 'levl', datetime.date(2005, 5, 1), 0.182)
# ('219018', 'disvol', datetime.date(2005, 5, 1), 0.477)
# ('219018', 'disc', datetime.date(2005, 5, 1), 0.403)
# ('409017', 'levl', datetime.date(2005, 5, 1), 1.502)
# ('409017', 'disvol', datetime.date(2005, 5, 1), 1279.157)
# ('409017', 'disc', datetime.date(2005, 5, 1), 1332.366)
# ('409017', 'temp', datetime.date(2005, 5, 1), 11.841)
# ('409017', 'ec', datetime.date(2005, 5, 1), 32.938)
# ('409204C', 'levl', datetime.date(2005, 5, 2), 0.693)
# ('409204C', 'disvol', datetime.date(2005, 5, 2), 2694.377)
# ('409204C', 'disc', datetime.date(2005, 5, 2), 2651.866)
# ('409204C', 'temp', datetime.date(2005, 5, 2), 14.642)
# ('409204C', 'ec', datetime.date(2005, 5, 2), 41.25)
# ('219018', 'levl', datetime.date(2005, 5, 2), 0.185)
# ('219018', 'disvol', datetime.date(2005, 5, 2), 0.532)
# ('219018', 'disc', datetime.date(2005, 5, 2), 0.545)
# ('409017', 'levl', datetime.date(2005, 5, 2), 1.52)
# ('409017', 'disvol', datetime.date(2005, 5, 2), 1346.752)
# ('409017', 'disc', datetime.date(2005, 5, 2), 1300.959)
# ('409017', 'temp', datetime.date(2005, 5, 2), 12.494)
# ('409017', 'ec', datetime.date(2005, 5, 2), 35.896)
# ('409204C', 'levl', datetime.date(2005, 5, 3), 0.67)
# ('409204C', 'disvol', datetime.date(2005, 5, 3), 2568.416)
# ('409204C', 'disc', datetime.date(2005, 5, 3), 2529.784)
# ('409204C', 'temp', datetime.date(2005, 5, 3), 14.453)
# ('409204C', 'ec', datetime.date(2005, 5, 3), 40.552)
# ('219018', 'levl', datetime.date(2005, 5, 3), 0.186)
# ('219018', 'disvol', datetime.date(2005, 5, 3), 0.545)
# ('219018', 'disc', datetime.date(2005, 5, 3), 0.545)
# ('409017', 'levl', datetime.date(2005, 5, 3), 1.486)
# ('409017', 'disvol', datetime.date(2005, 5, 3), 1218.943)
# ('409017', 'disc', datetime.date(2005, 5, 3), 1203.015)
# ('409017', 'temp', datetime.date(2005, 5, 3), 12.777)
# ('409017', 'ec', datetime.date(2005, 5, 3), 38.563)
# ('409204C', 'levl', datetime.date(2005, 5, 4), 0.653)
# ('409204C', 'disvol', datetime.date(2005, 5, 4), 2469.567)
# ('409204C', 'disc', datetime.date(2005, 5, 4), 2446.629)
# ('409204C', 'temp', datetime.date(2005, 5, 4), 14.483)
# ('409204C', 'ec', datetime.date(2005, 5, 4), 40.75)
# ('219018', 'levl', datetime.date(2005, 5, 4), 0.187)
# ('219018', 'disvol', datetime.date(2005, 5, 4), 0.561)
# ('219018', 'disc', datetime.date(2005, 5, 4), 0.588)
# ('409017', 'levl', datetime.date(2005, 5, 4), 1.48)
# ('409017', 'disvol', datetime.date(2005, 5, 4), 1195.763)
# ('409017', 'disc', datetime.date(2005, 5, 4), 1166.714)
# ('409017', 'temp', datetime.date(2005, 5, 4), 12.99)
# ('409017', 'ec', datetime.date(2005, 5, 4), 41.0)
# ('409204C', 'levl', datetime.date(2005, 5, 5), 0.644)
# ('409204C', 'disvol', datetime.date(2005, 5, 5), 2415.753)
# ('409204C', 'disc', datetime.date(2005, 5, 5), 2409.639)
# ('409204C', 'temp', datetime.date(2005, 5, 5), 14.373)
# ('409204C', 'ec', datetime.date(2005, 5, 5), 39.479)
# ('219018', 'levl', datetime.date(2005, 5, 5), 0.189)
# ('219018', 'disvol', datetime.date(2005, 5, 5), 0.644)
# ('219018', 'disc', datetime.date(2005, 5, 5), 0.719)
# ('409017', 'levl', datetime.date(2005, 5, 5), 1.47)
# ('409017', 'disvol', datetime.date(2005, 5, 5), 1158.526)
# ('409017', 'disc', datetime.date(2005, 5, 5), 1141.872)
# ('409017', 'temp', datetime.date(2005, 5, 5), 13.06)
# ('409017', 'ec', datetime.date(2005, 5, 5), 41.813)
# ('409204C', 'levl', datetime.date(2005, 5, 6), 0.641)
# ('409204C', 'disvol', datetime.date(2005, 5, 6), 2394.94)
# ('409204C', 'disc', datetime.date(2005, 5, 6), 2384.377)
# ('409204C', 'temp', datetime.date(2005, 5, 6), 14.25)
# ('409204C', 'ec', datetime.date(2005, 5, 6), 39.0)
# ('219018', 'levl', datetime.date(2005, 5, 6), 0.193)
# ('219018', 'disvol', datetime.date(2005, 5, 6), 0.746)
# ('219018', 'disc', datetime.date(2005, 5, 6), 0.735)
# ('409017', 'levl', datetime.date(2005, 5, 6), 1.471)
# ('409017', 'disvol', datetime.date(2005, 5, 6), 1161.829)
# ('409017', 'disc', datetime.date(2005, 5, 6), 1281.528)
# ('409017', 'temp', datetime.date(2005, 5, 6), 13.165)
# ('409017', 'ec', datetime.date(2005, 5, 6), 42.854)
# ('409204C', 'levl', datetime.date(2005, 5, 7), 0.634)
# ('409204C', 'disvol', datetime.date(2005, 5, 7), 2348.499)
# ('409204C', 'disc', datetime.date(2005, 5, 7), 2292.12)
# ('409204C', 'temp', datetime.date(2005, 5, 7), 14.05)
# ('409204C', 'ec', datetime.date(2005, 5, 7), 38.083)
# ('219018', 'levl', datetime.date(2005, 5, 7), 0.192)
# ('219018', 'disvol', datetime.date(2005, 5, 7), 0.728)
# ('219018', 'disc', datetime.date(2005, 5, 7), 0.727)
# ('409017', 'levl', datetime.date(2005, 5, 7), 1.524)
# ('409017', 'disvol', datetime.date(2005, 5, 7), 1365.544)
# ('409017', 'disc', datetime.date(2005, 5, 7), 1388.599)
# ('409017', 'temp', datetime.date(2005, 5, 7), 13.127)
# ('409017', 'ec', datetime.date(2005, 5, 7), 43.396)
# ('409204C', 'levl', datetime.date(2005, 5, 8), 0.617)
# ('409204C', 'disvol', datetime.date(2005, 5, 8), 2233.26)
# ('409204C', 'disc', datetime.date(2005, 5, 8), 2185.795)
# ('409204C', 'temp', datetime.date(2005, 5, 8), 14.019)
# ('409204C', 'ec', datetime.date(2005, 5, 8), 37.385)
# ('409017', 'levl', datetime.date(2005, 5, 8), 1.507)
# ('409017', 'disvol', datetime.date(2005, 5, 8), 1298.944)
# ('409017', 'disc', datetime.date(2005, 5, 8), 1072.179)
# ('409017', 'temp', datetime.date(2005, 5, 8), 13.105)
# ('409017', 'ec', datetime.date(2005, 5, 8), 43.578)
# ('409204C', 'levl', datetime.date(2005, 5, 9), 0.588)
# ('409204C', 'disvol', datetime.date(2005, 5, 9), 2099.64)
# ('409204C', 'disc', datetime.date(2005, 5, 9), 2060.874)
# ('409204C', 'temp', datetime.date(2005, 5, 9), 14.15)
# ('409204C', 'ec', datetime.date(2005, 5, 9), 37.76)
# ('219018', 'disc', datetime.date(2005, 5, 9), 0.801)
# ('409017', 'levl', datetime.date(2005, 5, 9), 1.472)
# ('409017', 'disvol', datetime.date(2005, 5, 9), 1166.936)
# ('409017', 'disc', datetime.date(2005, 5, 9), 1225.026)
# ('409017', 'temp', datetime.date(2005, 5, 9), 12.873)
# ('409017', 'ec', datetime.date(2005, 5, 9), 42.333)
# ('409204C', 'levl', datetime.date(2005, 5, 10), 0.555)
# ('409204C', 'disvol', datetime.date(2005, 5, 10), 2023.948)
# ('409204C', 'disc', datetime.date(2005, 5, 10), 1994.499)
# ('409204C', 'temp', datetime.date(2005, 5, 10), 14.104)
# ('409204C', 'ec', datetime.date(2005, 5, 10), 38.385)
# ('219018', 'levl', datetime.date(2005, 5, 10), 0.196)
# ('219018', 'disvol', datetime.date(2005, 5, 10), 0.852)
# ('219018', 'disc', datetime.date(2005, 5, 10), 0.794)
# ('409017', 'levl', datetime.date(2005, 5, 10), 1.494)
# ('409017', 'disvol', datetime.date(2005, 5, 10), 1246.048)
# ('409017', 'disc', datetime.date(2005, 5, 10), 1192.099)
# ('409017', 'temp', datetime.date(2005, 5, 10), 12.998)
# ('409017', 'ec', datetime.date(2005, 5, 10), 40.958)
# ('409204C', 'levl', datetime.date(2005, 5, 11), 0.534)
# ('409204C', 'disvol', datetime.date(2005, 5, 11), 1958.392)
# ('409204C', 'disc', datetime.date(2005, 5, 11), 1959.86)
# ('409204C', 'temp', datetime.date(2005, 5, 11), 14.054)
# ('409204C', 'ec', datetime.date(2005, 5, 11), 38.646)
# ('219018', 'levl', datetime.date(2005, 5, 11), 0.191)
# ('219018', 'disvol', datetime.date(2005, 5, 11), 0.705)
# ('219018', 'disc', datetime.date(2005, 5, 11), 0.903)
# ('409017', 'levl', datetime.date(2005, 5, 11), 1.473)
# ('409017', 'disvol', datetime.date(2005, 5, 11), 1168.779)
# ('409017', 'disc', datetime.date(2005, 5, 11), 1192.099)
# ('409017', 'temp', datetime.date(2005, 5, 11), 12.958)
# ('409017', 'ec', datetime.date(2005, 5, 11), 40.958)
# ('409204C', 'levl', datetime.date(2005, 5, 12), 0.538)
# ('409204C', 'disvol', datetime.date(2005, 5, 12), 1975.382)
# ('409204C', 'disc', datetime.date(2005, 5, 12), 1991.358)
# ('409204C', 'temp', datetime.date(2005, 5, 12), 14.017)
# ('409204C', 'ec', datetime.date(2005, 5, 12), 38.667)
# ('219018', 'levl', datetime.date(2005, 5, 12), 0.193)
# ('219018', 'disvol', datetime.date(2005, 5, 12), 0.772)
# ('219018', 'disc', datetime.date(2005, 5, 12), 0.925)
# ('409017', 'levl', datetime.date(2005, 5, 12), 1.486)
# ('409017', 'disvol', datetime.date(2005, 5, 12), 1219.034)
# ('409017', 'disc', datetime.date(2005, 5, 12), 1217.812)
# ('409017', 'temp', datetime.date(2005, 5, 12), 12.877)
# ('409017', 'ec', datetime.date(2005, 5, 12), 40.771)
# ('409204C', 'levl', datetime.date(2005, 5, 13), 0.546)
# ('409204C', 'disvol', datetime.date(2005, 5, 13), 2000.689)
# ('409204C', 'disc', datetime.date(2005, 5, 13), 2011.907)
# ('409204C', 'temp', datetime.date(2005, 5, 13), 13.792)
# ('409204C', 'ec', datetime.date(2005, 5, 13), 38.5)
# ('219018', 'levl', datetime.date(2005, 5, 13), 0.193)
# ('219018', 'disvol', datetime.date(2005, 5, 13), 0.753)
# ('219018', 'disc', datetime.date(2005, 5, 13), 0.812)
# ('409017', 'levl', datetime.date(2005, 5, 13), 1.484)
# ('409017', 'disvol', datetime.date(2005, 5, 13), 1212.056)
# ('409017', 'disc', datetime.date(2005, 5, 13), 1217.812)
# ('409017', 'temp', datetime.date(2005, 5, 13), 12.571)
# ('409017', 'ec', datetime.date(2005, 5, 13), 40.583)
# ('409204C', 'levl', datetime.date(2005, 5, 14), 0.553)
# ('409204C', 'disvol', datetime.date(2005, 5, 14), 2018.924)
# ('409204C', 'disc', datetime.date(2005, 5, 14), 2043.983)
# ('409204C', 'temp', datetime.date(2005, 5, 14), 13.757)
# ('409204C', 'ec', datetime.date(2005, 5, 14), 45.438)
# ('409017', 'levl', datetime.date(2005, 5, 14), 1.487)
# ('409017', 'disvol', datetime.date(2005, 5, 14), 1222.575)
# ('409017', 'disc', datetime.date(2005, 5, 14), 1228.869)
# ('409017', 'temp', datetime.date(2005, 5, 14), 12.677)
# ('409017', 'ec', datetime.date(2005, 5, 14), 40.104)
# ('409204C', 'levl', datetime.date(2005, 5, 15), 0.577)
# ('409204C', 'disvol', datetime.date(2005, 5, 15), 2072.097)
# ('409204C', 'disc', datetime.date(2005, 5, 15), 2094.728)
# ('409204C', 'temp', datetime.date(2005, 5, 15), 13.851)
# ('409204C', 'ec', datetime.date(2005, 5, 15), 38.01)
# ('409017', 'levl', datetime.date(2005, 5, 15), 1.492)
# ('409017', 'disvol', datetime.date(2005, 5, 15), 1239.378)
# ('409017', 'disc', datetime.date(2005, 5, 15), 1251.162)
# ('409017', 'temp', datetime.date(2005, 5, 15), 12.888)
# ('409017', 'ec', datetime.date(2005, 5, 15), 40.75)
# ('409204C', 'levl', datetime.date(2005, 5, 16), 0.604)
# ('409204C', 'disvol', datetime.date(2005, 5, 16), 2153.007)
# ('409204C', 'disc', datetime.date(2005, 5, 16), 2312.337)
# ('409204C', 'temp', datetime.date(2005, 5, 16), 14.198)
# ('409204C', 'ec', datetime.date(2005, 5, 16), 39.729)
# ('409017', 'levl', datetime.date(2005, 5, 16), 1.471)
# ('409017', 'disvol', datetime.date(2005, 5, 16), 1170.961)
# ('409017', 'disc', datetime.date(2005, 5, 16), 895.048)
# ('409017', 'temp', datetime.date(2005, 5, 16), 13.187)
# ('409017', 'ec', datetime.date(2005, 5, 16), 41.469)
# ('409204C', 'levl', datetime.date(2005, 5, 17), 0.66)
# ('409204C', 'disvol', datetime.date(2005, 5, 17), 2508.258)
# ('409204C', 'disc', datetime.date(2005, 5, 17), 2678.357)
# ('409204C', 'temp', datetime.date(2005, 5, 17), 13.862)
# ('409204C', 'ec', datetime.date(2005, 5, 17), 39.063)
# ('409017', 'levl', datetime.date(2005, 5, 17), 1.537)
# ('409017', 'disvol', datetime.date(2005, 5, 17), 1485.14)
# ('409017', 'disc', datetime.date(2005, 5, 17), 1979.05)
# ('409017', 'temp', datetime.date(2005, 5, 17), 11.971)
# ('409017', 'ec', datetime.date(2005, 5, 17), 37.385)
# ('409204C', 'levl', datetime.date(2005, 5, 18), 0.705)
# ('409204C', 'disvol', datetime.date(2005, 5, 18), 2771.722)
# ('409204C', 'disc', datetime.date(2005, 5, 18), 2824.684)
# ('409204C', 'temp', datetime.date(2005, 5, 18), 13.815)
# ('409204C', 'ec', datetime.date(2005, 5, 18), 38.708)
# ('409017', 'levl', datetime.date(2005, 5, 18), 1.597)
# ('409017', 'disvol', datetime.date(2005, 5, 18), 1681.742)
# ('409017', 'disc', datetime.date(2005, 5, 18), 1376.256)
# ('409017', 'temp', datetime.date(2005, 5, 18), 11.011)
# ('409017', 'ec', datetime.date(2005, 5, 18), 31.115)
# ('409204C', 'levl', datetime.date(2005, 5, 19), 0.713)
# ('409204C', 'disvol', datetime.date(2005, 5, 19), 2827.017)
# ('409204C', 'disc', datetime.date(2005, 5, 19), 2824.684)
# ('409204C', 'temp', datetime.date(2005, 5, 19), 13.85)
# ('409204C', 'ec', datetime.date(2005, 5, 19), 39.5)
# ('409017', 'levl', datetime.date(2005, 5, 19), 1.489)
# ('409017', 'disvol', datetime.date(2005, 5, 19), 1229.131)
# ('409017', 'disc', datetime.date(2005, 5, 19), 1141.872)
# ('409017', 'temp', datetime.date(2005, 5, 19), 10.983)
# ('409017', 'ec', datetime.date(2005, 5, 19), 30.646)
# ('409204C', 'levl', datetime.date(2005, 5, 20), 0.716)
# ('409204C', 'disvol', datetime.date(2005, 5, 20), 2844.83)
# ('409204C', 'disc', datetime.date(2005, 5, 20), 2881.561)
# ('409204C', 'temp', datetime.date(2005, 5, 20), 14.058)
# ('409204C', 'ec', datetime.date(2005, 5, 20), 41.75)
# ('409017', 'levl', datetime.date(2005, 5, 20), 1.48)
# ('409017', 'disvol', datetime.date(2005, 5, 20), 1196.098)
# ('409017', 'disc', datetime.date(2005, 5, 20), 1225.026)
# ('409017', 'temp', datetime.date(2005, 5, 20), 11.454)
# ('409017', 'ec', datetime.date(2005, 5, 20), 32.125)
# ('409204C', 'levl', datetime.date(2005, 5, 21), 0.731)
# ('409204C', 'disvol', datetime.date(2005, 5, 21), 2951.734)
# ('409204C', 'disc', datetime.date(2005, 5, 21), 3033.432)
# ('409204C', 'temp', datetime.date(2005, 5, 21), 14.04)
# ('409204C', 'ec', datetime.date(2005, 5, 21), 41.813)
# ('409017', 'levl', datetime.date(2005, 5, 21), 1.488)
# ('409017', 'disvol', datetime.date(2005, 5, 21), 1227.102)
# ('409017', 'disc', datetime.date(2005, 5, 21), 1266.311)
# ('409017', 'temp', datetime.date(2005, 5, 21), 11.583)
# ('409017', 'ec', datetime.date(2005, 5, 21), 32.813)
# ('409204C', 'levl', datetime.date(2005, 5, 22), 0.756)
# ('409204C', 'disvol', datetime.date(2005, 5, 22), 3121.649)
# ('409204C', 'disc', datetime.date(2005, 5, 22), 3230.753)
# ('409204C', 'temp', datetime.date(2005, 5, 22), 13.95)
# ('409204C', 'ec', datetime.date(2005, 5, 22), 42.521)
# ('409017', 'levl', datetime.date(2005, 5, 22), 1.5)
# ('409017', 'disvol', datetime.date(2005, 5, 22), 1269.301)
# ('409017', 'disc', datetime.date(2005, 5, 22), 1254.824)
# ('409017', 'temp', datetime.date(2005, 5, 22), 11.585)
# ('409017', 'ec', datetime.date(2005, 5, 22), 32.271)
# SELECT count(*) FROM Measurement
# (1793,)

# %% [markdown]
# ## Your Task: Data Storage in PostgreSQL
# Following the above pattern, make sure all the   tables of our water schema are loaded with the data from the different CSV files.

# %%
# TODO: replace the content of this cell with your Python + SQL solution
if conn is None or conn.closed:
    conn = pgconnect()
    
# check for any existing content of the Organisations table
query_stmt = "SELECT COUNT(*) FROM Organisation"
print(query_stmt) 
pgquery(conn, query_stmt, None) 

# check content of Station table
query_stmt = "SELECT count(*) FROM Station"
print(query_stmt) 
pgquery(conn, query_stmt, None) 

# check content of Station table
query_stmt = "SELECT count(*) FROM Sensor"
print(query_stmt) 
pgquery(conn, query_stmt, None) 

# check content of Measurements table
query_stmt = "SELECT count(*) FROM Measurement"
print(query_stmt) 
pgquery(conn, query_stmt, None)
# Out:
# connected
# SELECT COUNT(*) FROM Organisation
# (9,)
# SELECT count(*) FROM Station
# (9,)
# SELECT count(*) FROM Sensor
# (7,)
# SELECT count(*) FROM Measurement
# (1793,)
# True

# %% [markdown]
# # End of Exercise. Many Thanks.
